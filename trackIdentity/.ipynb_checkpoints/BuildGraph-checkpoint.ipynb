# %%
import pandas as pd
import pickle
import itertools
from ast import literal_eval

# %%
gdf = pickle.load(open('/home/osboxes/proj/twitter/trackIdentity/graphdf.pkl', 'rb'))
filename = '/home/osboxes/proj/twitter/tweets.data'

# %%
def RetrieveTweetsFromLastPoint(filename,LineMemorisied):

    # Initialisation
    maliste = []
    errors = 0
    ntweets = 0
    
    # Read New Tweets
    with open(filename) as fp:
        for line in fp:
            ntweets = ntweets + 1 
            if ntweets > LineMemorisied:
                try:
                    maliste.append(literal_eval(line))
                except:
                    errors = errors + 1

    return maliste,errors,ntweets,LineMemorisied

# %%
maliste,NewErrors,NewNtweets,NewLineMemorisied = RetrieveTweetsFromLastPoint(filename,0)

# %%
tdf = pd.DataFrame(maliste)

# %%
# tdf.sort_values(by="USERFNAME",ascending=False)

# %%
a = tdf[["USERNAME",
         "USERID",
         "USERFOLLOWERS",
         "USERFNAME",
         "USERDESCRIPTION"]].\
rename(columns = {"USERNAME" : "NAME",
                  "USERID" : "ID",
                  "USERFOLLOWERS" : "NFOL",
                  "USERFNAME" : "FNAME",
                  "USERDESCRIPTION":"DESCRIPTION"})

b = tdf[["AUTHORNAME",
         "AUTHORID",
         "AUTHORFOLLOWERS",
         "AUTHORFNAME",
         "AUTHORDESCRIPTION"]].\
rename(columns = {"AUTHORNAME" : "NAME",
                  "AUTHORID" : "ID",
                  "AUTHORFOLLOWERS" :"NFOL",
                  "AUTHORFNAME":"FNAME",
                  "AUTHORDESCRIPTION":"DESCRIPTION"})

# %%
tdf = pd.concat([a,b],axis=0, sort=False)
tdf.sort_values(by="FNAME",ascending=False,inplace=True)

# %%
tdf = tdf.drop_duplicates(subset = ["ID"])

final = gdf.\
merge(tdf,how="left",left_on="A",right_on="ID",).\
rename(columns = {"NAME" : "ANAME",
                  "NFOL":"ANFOL",
                  "DESCRIPTION" : "ADESCRIPTION","FNAME":"AFNAME"}).drop(columns='ID')

final = final.\
merge(tdf,how="left",left_on="B",right_on="ID").\
rename(columns = {"NAME" : "BNAME",
                  "NFOL":"BNFOL",
                  "DESCRIPTION" : "BDESCRIPTION","FNAME":"BFNAME"}).drop(columns=['ID'])

final.sort_values(by="f",ascending=False,inplace=True)
final = final[final.A != final.B]
final.reset_index(drop=True,inplace=True)

# %%
final.head()
# Out:
#                      A                    B   f            ANAME  ANFOL  \
# 0             33962372  1121856729787043842  18    ChLECHEVALIER  20950
# 1  1121856729787043842             33962372  18    stephaneworld    270
# 2           3373762791            572122341  15      GWGoldnadel  89338
# 3   727425382169849856   827151086733635584  15  Olivier_Monteil  12897
# 4   727425382169849856   901893722857766912  15  Olivier_Monteil  12897
#
#                 AFNAME                                       ADESCRIPTION  \
# 0       Ch.LECHEVALIER  Gaulliste, ex-RPR / DLR, avec Marine en Ille &...
# 1              𝑺𝑻𝑬𝑭𝑭 ✞  La France ⚜, mon royaume, terre de mes ancêtre...
# 2  G-William Goldnadel  Avocat, essayiste, président d'Avocats sans fr...
# 3      Olivier MONTEIL  Conseiller régional RN #Occitanie I Membre du ...
# 4      Olivier MONTEIL  Conseiller régional RN #Occitanie I Membre du ...
#
#              BNAME  BNFOL           BFNAME  \
# 0    stephaneworld    270          𝑺𝑻𝑬𝑭𝑭 ✞
# 1    ChLECHEVALIER  20950   Ch.LECHEVALIER
# 2  tprincedelamour  24364         Napoléon
# 3     dragonduclos  14759        Barbara78
# 4     Fredodu13007    663  fred 🇫🇷🇫🇷🇷🇺🇮🇹✈️
#
#                                         BDESCRIPTION
# 0  La France ⚜, mon royaume, terre de mes ancêtre...
# 1  Gaulliste, ex-RPR / DLR, avec Marine en Ille &...
# 2  J'Œuvre au Rassemblement des #Patriotes pour s...
# 3  Il est toujours beaucoup plus tard qu'on ne le...
# 4                        suis moi et tu verras 🤷🏻‍♂️

# %%
pickle.dump(final, open('/home/osboxes/proj/twitter/trackIdentity/GraphIdentity.pkl', 'wb'))

# %%
print("Nombre de links :",len(final))
# Out:
# Nombre de links : 3218

# %%
print("")
print(final[["A","B","f"]].head())
# Out:
# <bound method NDFrame.head of                         A                    B   f
# 0     1121856729787043842             33962372  17
# 1                33962372  1121856729787043842  17
# 2      727425382169849856   901893722857766912  15
# 3      727425382169849856   827151086733635584  15
# 4     1121856729787043842   901893722857766912  14
# ...                   ...                  ...  ..
# 3213           2986275514           2752784274   1
# 3214           2986275514           2770357902   1
# 3215           2986275514            299730426   1
# 3216           2986275514             29977884   1
# 3217   996378340331261952           2877116435   1
#
# [3218 rows x 3 columns]>

# %%
final.to_csv("graph.csv",index=False)

# %%
final.sort_values(by="")
# Out:
#                      A                    B   f ANAME  ANFOL          FNAME_x  \
# 0             33962372  1121856729787043842  18   NaN  20950    ChLECHEVALIER
# 1  1121856729787043842             33962372  18   NaN    267    stephaneworld
# 2           3373762791            572122341  15   NaN  89338      GWGoldnadel
# 3   727425382169849856   827151086733635584  15   NaN  12897  Olivier_Monteil
# 4   727425382169849856   901893722857766912  15   NaN  12897  Olivier_Monteil
#
#                                         ADESCRIPTION        AUTHORFNAME_x  \
# 0  Gaulliste, ex-RPR / DLR, avec Marine en Ille &...       Ch.LECHEVALIER
# 1  La France ⚜, mon royaume, terre de mes ancêtre...              𝑺𝑻𝑬𝑭𝑭 ✞
# 2  Avocat, essayiste, président d'Avocats sans fr...  G-William Goldnadel
# 3  Conseiller régional RN #Occitanie I Membre du ...      Olivier MONTEIL
# 4  Conseiller régional RN #Occitanie I Membre du ...      Olivier MONTEIL
#
#   BNAME  BNFOL          FNAME_y  \
# 0   NaN    267    stephaneworld
# 1   NaN  20950    ChLECHEVALIER
# 2   NaN  24363  tprincedelamour
# 3   NaN  14758     dragonduclos
# 4   NaN    663     Fredodu13007
#
#                                         BDESCRIPTION    AUTHORFNAME_y
# 0  La France ⚜, mon royaume, terre de mes ancêtre...          𝑺𝑻𝑬𝑭𝑭 ✞
# 1  Gaulliste, ex-RPR / DLR, avec Marine en Ille &...   Ch.LECHEVALIER
# 2  J'Œuvre au Rassemblement des #Patriotes pour s...         Napoléon
# 3  Il est toujours beaucoup plus tard qu'on ne le...        Barbara78
# 4                        suis moi et tu verras 🤷🏻‍♂️  fred 🇫🇷🇫🇷🇷🇺🇮🇹✈️
